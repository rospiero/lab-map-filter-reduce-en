# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy
import pandas

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
prophet = prophet[568:]

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
print(prophet[1:10])
# Out:
# ['the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def remove_reference(word):
    return word.split('{')[0]
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
prophet_reference = list(map(remove_reference, prophet))
print(prophet_reference[1:10])
# Out:
# ['the', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(word):
    return word.split('\n')

# Apply the function to each word in the list and flatten the result using list comprehension
# Check the result
print(line_break('the\nbeloved'))
# Out:
# ['the', 'beloved']

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
mapped = map(line_break, prophet_reference)
prophet_line = [part for sublist in mapped for part in sublist]
print(prophet_line[0:10])
# Out:
# ['PROPHET', '', '|Almustafa,', 'the', 'chosen', 'and', 'the', 'beloved,', 'who', 'was']

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [word for sublist in prophet_line for word in sublist]

print(prophet_flat[0:10])
# Out:
# ['P', 'R', 'O', 'P', 'H', 'E', 'T', '|', 'A', 'l']

# %%
# your code here

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    if x in word_list:
        return False
    else:
        return True

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
prophet_filter = list(filter(word_filter, prophet_flat))
print(prophet_filter[:10])
# Out:
# ['P', 'R', 'O', 'P', 'H', 'E', 'T', '|', 'A', 'l']

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    return a + ' ' + b

# %%
# your code here

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
def concat_space(a, b):
    return a + ' ' + b

prophet_string = reduce(concat_space, prophet_filter)

print(prophet_string)
# Out:
# P R O P H E T | A l m u s t f , t h e c h o s e n n d t h e b e l o v e d , w h o w s d w n u n t o h i s o w n d y , h d w i t e d t w e l v e y e r s i n t h e c i t y o f O r p h l e s e f o r h i s s h i p t h t w s t o r e t u r n n d b e r h i m b c k t o t h e i s l e o f h i s b i r t h . A n d i n t h e t w e l f t h y e r , o n t h e s e v e n t h d y o f I e l o o l , t h e m o n t h o f r e p i n g , h e c l i m b e d t h e h i l l w i t h o u t t h e c i t y w l l s n d l o o k e d s e w r d ; n d h e b e h e l d h i s s h i p c o m i n g w i t h t h e m i s t . T h e n t h e g t e s o f h i s h e r t w e r e f l u n g o p e n , n d h i s j o y f l e w f r o v e r t h e s e . A n d h e c l o s e d h i s e y e s n d p r y e d i n t h e s i l e n c e s o f h i s s o u l . * * * * * B u t s h e d e s c e n d e d t h e h i l l , s d n e s s c m e u p o n h i m , n d h e t h o u g h t i n h i s h e r t : H o w s h l l I g o i n p e c e n d w i t h o u t s o r r o w ? N y , n o t w i t h o u t w o u n d i n t h e s p i r i t s h l l I l e v e t h i s c i t y . t h e d y s o f p i n I h v e s p e n t w i t h i n i t s w l l s , n d l o n g w e r e t h e n i g h t s o f l o n e n e s s ; n d w h o c n d e p r t f r o m h i s p i n n d h i s l o n e n e s s w i t h o u t r e g r e t ? T o o m n y f r g m e n t s o f t h e s p i r i t h v e I s c t t e r e d i n t h e s e s t r e e t s , n d t o o m n y r e t h e c h i l d r e n o f m y l o n g i n g t h t w l k n k e d m o n g t h e s e h i l l s , n d I c n n o t w i t h d r w f r o m t h e m w i t h o u t b u r d e n n d n c h e . I t i s n o t g r m e n t I c s t o f f t h i s d y , b u t s k i n t h t I t e r w i t h m y o w n h n d s . N o r i s i t t h o u g h t I l e v e b e h i n d m e , b u t h e r t m d e s w e e t w i t h h u n g e r n d w i t h t h i r s t . * * * * * Y e t I c n n o t t r r y l o n g e r . T h e s e t h t c l l s l l t h i n g s u n t o h e r c l l s m e , n d I m u s t e m b r k . F o r t o s t y , t h o u g h t h e h o u r s b u r n i n t h e n i g h t , i s t o f r e e z e n d c r y s t l l i z e n d b e b o u n d i n m o u l d . F i n w o u l d I t k e w i t h m e l l t h t i s h e r e . B u t h o w s h l l I ? A v o i c e c n n o t c r r y t h e t o n g u e n d l i p s t h t g v e i t w i n g s . A l o n e m u s t i t s e e k t h e e t h e r . A n d l o n e n d w i t h o u t h i s n e s t s h l l t h e e g l e f l y c r o s s t h e s u n . * * * * * N o w w h e n h e r e c h e d t h e f o o t o f t h e h i l l , h e t u r n e d g i n t o w r d s t h e s e , n d h e s w h i s s h i p p p r o c h i n g t h e h r b o u r , n d u p o n h e r p r o w t h e m r i n e r s , t h e m e n o f h i s o w n l n d . A n d h i s s o u l c r i e d o u t t o t h e m , n d h e s i d : S o n s o f m y n c i e n t m o t h e r , y o u r i d e r s o f t h e t i d e s , H o w o f t e n h v e y o u s i l e d i n m y d r e m s . A n d n o w y o u c o m e i n m y w k e n i n g , w h i c h i s m y d e e p e r d r e m . R e d y m I t o g o , n d m y e g e r n e s s w i t h s i l s f u l l s e t w i t s t h e w i n d . O n l y n o t h e r b r e t h w i l l I b r e t h e i n t h i s s t i l l i r , o n l y n o t h e r l o v i n g l o o k c s t b c k w r d , A n d t h e n I s h l l s t n d m o n g y o u , s e f r e r m o n g s e f r e r s . y o u , v s t s e , s l e e p l e s s m o t h e r , W h o l o n e r e p e c e n d f r e e d o m t o t h e r i v e r n d t h e s t r e m , O n l y n o t h e r w i n d i n g w i l l t h i s s t r e m m k e , o n l y n o t h e r m u r m u r i n t h i s g l d e , A n d t h e n s h l l I c o m e t o y o u , b o u n d l e s s d r o p t o b o u n d l e s s o c e n . * * * * * A n d s h e w l k e d h e s w f r o m f r m e n n d w o m e n l e v i n g t h e i r f i e l d s n d t h e i r v i n e y r d s n d h s t e n i n g t o w r d s t h e c i t y g t e s . A n d h e h e r d t h e i r v o i c e s c l l i n g h i s n m e , n d s h o u t i n g  ...
